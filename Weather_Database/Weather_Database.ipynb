# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 735

# %%
# Import the requests library.
import requests

# Import the time library.
import time

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | dingle
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | yulara
# Processing Record 8 of Set 1 | cidreira
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | sabha
# Processing Record 13 of Set 1 | udachnyy
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | namibe
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | riviere-du-loup
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | arica
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | ponta do sol
# Processing Record 27 of Set 1 | aguimes
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | grandview
# Processing Record 30 of Set 1 | pacific grove
# Processing Record 31 of Set 1 | songea
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | clyde river
# Processing Record 34 of Set 1 | hamina
# Processing Record 35 of Set 1 | hasaki
# Processing Record 36 of Set 1 | vestmannaeyjar
# Processing Record 37 of Set 1 | san quintin
# Processing Record 38 of Set 1 | vardo
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | norman wells
# Processing Record 41 of Set 1 | lhokseumawe
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | urrutia
# Processing Record 45 of Set 1 | najran
# Processing Record 46 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | zhigalovo
# Processing Record 49 of Set 1 | garden city
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | birchis
# Processing Record 2 of Set 2 | nanakuli
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 2 | ionia
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | kavieng
# Processing Record 8 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 2 | ngorongoro
# Processing Record 10 of Set 2 | port arthur
# Processing Record 11 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | sirnak
# Processing Record 17 of Set 2 | kahului
# Processing Record 18 of Set 2 | los alamos
# Processing Record 19 of Set 2 | snyder
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | barcelona
# Processing Record 22 of Set 2 | bouna
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | taft
# Processing Record 25 of Set 2 | mahebourg
# Processing Record 26 of Set 2 | lorengau
# Processing Record 27 of Set 2 | barcelos
# Processing Record 28 of Set 2 | leona vicario
# Processing Record 29 of Set 2 | avera
# Processing Record 30 of Set 2 | launceston
# Processing Record 31 of Set 2 | parit buntar
# Processing Record 32 of Set 2 | galveston
# Processing Record 33 of Set 2 | corner brook
# Processing Record 34 of Set 2 | panguna
# Processing Record 35 of Set 2 | bowen
# Processing Record 36 of Set 2 | edd
# Processing Record 37 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 2 | mangaratiba
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | tyrma
# Processing Record 41 of Set 2 | adamovka
# Processing Record 42 of Set 2 | ostrovnoy
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | hami
# Processing Record 45 of Set 2 | novotroitskaya
# Processing Record 46 of Set 2 | half moon bay
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | luderitz
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | vaini
# Processing Record 1 of Set 3 | waipawa
# Processing Record 2 of Set 3 | nuevo progreso
# Processing Record 3 of Set 3 | ambovombe
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | aitape
# Processing Record 6 of Set 3 | taoudenni
# Processing Record 7 of Set 3 | mpika
# Processing Record 8 of Set 3 | manyana
# Processing Record 9 of Set 3 | mangrol
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | alice springs
# Processing Record 13 of Set 3 | yar-sale
# Processing Record 14 of Set 3 | verkhnevilyuysk
# Processing Record 15 of Set 3 | leningradskiy
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | guilin
# Processing Record 18 of Set 3 | upernavik
# Processing Record 19 of Set 3 | berikulskiy
# City not found. Skipping...
# Processing Record 20 of Set 3 | anchorage
# Processing Record 21 of Set 3 | faanui
# Processing Record 22 of Set 3 | hokitika
# Processing Record 23 of Set 3 | mount gambier
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | longyearbyen
# Processing Record 26 of Set 3 | karatau
# Processing Record 27 of Set 3 | khatanga
# Processing Record 28 of Set 3 | svetlaya
# Processing Record 29 of Set 3 | moses lake
# Processing Record 30 of Set 3 | vila franca do campo
# Processing Record 31 of Set 3 | korla
# Processing Record 32 of Set 3 | nanortalik
# Processing Record 33 of Set 3 | bredasdorp
# Processing Record 34 of Set 3 | beloha
# Processing Record 35 of Set 3 | itarema
# Processing Record 36 of Set 3 | albemarle
# Processing Record 37 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 3 | caravelas
# Processing Record 39 of Set 3 | pisco
# Processing Record 40 of Set 3 | ancud
# Processing Record 41 of Set 3 | bacum
# Processing Record 42 of Set 3 | victoria
# Processing Record 43 of Set 3 | chagoda
# Processing Record 44 of Set 3 | ilhabela
# Processing Record 45 of Set 3 | touros
# Processing Record 46 of Set 3 | hualmay
# Processing Record 47 of Set 3 | saint george
# Processing Record 48 of Set 3 | hilo
# Processing Record 49 of Set 3 | saint-philippe
# Processing Record 50 of Set 3 | buala
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | aleksandrov gay
# Processing Record 4 of Set 4 | oistins
# Processing Record 5 of Set 4 | san nicolas
# Processing Record 6 of Set 4 | biak
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | lagoa
# Processing Record 9 of Set 4 | wenling
# Processing Record 10 of Set 4 | hurghada
# Processing Record 11 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 4 | colombia
# Processing Record 13 of Set 4 | bilibino
# Processing Record 14 of Set 4 | georgetown
# Processing Record 15 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 4 | koutsouras
# Processing Record 17 of Set 4 | sioux lookout
# Processing Record 18 of Set 4 | lazaro cardenas
# Processing Record 19 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 4 | maldonado
# Processing Record 21 of Set 4 | ribeira grande
# Processing Record 22 of Set 4 | catamarca
# Processing Record 23 of Set 4 | sao filipe
# Processing Record 24 of Set 4 | sao joao da barra
# Processing Record 25 of Set 4 | kamenka
# Processing Record 26 of Set 4 | aksarka
# Processing Record 27 of Set 4 | te anau
# Processing Record 28 of Set 4 | faya
# Processing Record 29 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 30 of Set 4 | grootfontein
# Processing Record 31 of Set 4 | gola gokarannath
# Processing Record 32 of Set 4 | pervomayskoye
# Processing Record 33 of Set 4 | djibo
# Processing Record 34 of Set 4 | carnarvon
# Processing Record 35 of Set 4 | souillac
# Processing Record 36 of Set 4 | bandarbeyla
# Processing Record 37 of Set 4 | san martin
# Processing Record 38 of Set 4 | bethel
# Processing Record 39 of Set 4 | taganak
# Processing Record 40 of Set 4 | kudahuvadhoo
# Processing Record 41 of Set 4 | prince rupert
# Processing Record 42 of Set 4 | tornio
# Processing Record 43 of Set 4 | zhigansk
# Processing Record 44 of Set 4 | stornoway
# Processing Record 45 of Set 4 | saskylakh
# Processing Record 46 of Set 4 | broken hill
# Processing Record 47 of Set 4 | matveyevka
# Processing Record 48 of Set 4 | tokur
# Processing Record 49 of Set 4 | praia da vitoria
# Processing Record 50 of Set 4 | kungurtug
# Processing Record 1 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 5 | pyay
# Processing Record 5 of Set 5 | antalaha
# Processing Record 6 of Set 5 | rocha
# Processing Record 7 of Set 5 | husavik
# Processing Record 8 of Set 5 | fortuna
# Processing Record 9 of Set 5 | dubrovnik
# Processing Record 10 of Set 5 | aklavik
# Processing Record 11 of Set 5 | buchanan
# Processing Record 12 of Set 5 | bata
# Processing Record 13 of Set 5 | bluff
# Processing Record 14 of Set 5 | cherskiy
# Processing Record 15 of Set 5 | san cristobal
# Processing Record 16 of Set 5 | nueva loja
# Processing Record 17 of Set 5 | boa vista
# Processing Record 18 of Set 5 | konya
# Processing Record 19 of Set 5 | rudnogorsk
# Processing Record 20 of Set 5 | maceio
# Processing Record 21 of Set 5 | amalapuram
# Processing Record 22 of Set 5 | charters towers
# Processing Record 23 of Set 5 | arraial do cabo
# Processing Record 24 of Set 5 | malakwal
# Processing Record 25 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 5 | lewiston
# Processing Record 27 of Set 5 | baoding
# Processing Record 28 of Set 5 | iquique
# Processing Record 29 of Set 5 | wyndham
# Processing Record 30 of Set 5 | keti bandar
# Processing Record 31 of Set 5 | araouane
# Processing Record 32 of Set 5 | talaya
# Processing Record 33 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 34 of Set 5 | beyneu
# Processing Record 35 of Set 5 | cape town
# Processing Record 36 of Set 5 | ilulissat
# Processing Record 37 of Set 5 | ahuimanu
# Processing Record 38 of Set 5 | horsham
# Processing Record 39 of Set 5 | ormara
# Processing Record 40 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 5 | castro
# Processing Record 42 of Set 5 | padang
# Processing Record 43 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 44 of Set 5 | chokurdakh
# Processing Record 45 of Set 5 | guerrero negro
# Processing Record 46 of Set 5 | ternate
# Processing Record 47 of Set 5 | flin flon
# Processing Record 48 of Set 5 | taltal
# Processing Record 49 of Set 5 | esso
# Processing Record 50 of Set 5 | huarmey
# Processing Record 1 of Set 6 | annonay
# Processing Record 2 of Set 6 | sinnamary
# Processing Record 3 of Set 6 | bambanglipuro
# Processing Record 4 of Set 6 | lasa
# Processing Record 5 of Set 6 | acapulco
# Processing Record 6 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 6 | dongsheng
# Processing Record 8 of Set 6 | port hedland
# Processing Record 9 of Set 6 | buraydah
# Processing Record 10 of Set 6 | zavitinsk
# Processing Record 11 of Set 6 | esperance
# Processing Record 12 of Set 6 | yeppoon
# Processing Record 13 of Set 6 | grindavik
# Processing Record 14 of Set 6 | provideniya
# Processing Record 15 of Set 6 | sitka
# Processing Record 16 of Set 6 | sangar
# Processing Record 17 of Set 6 | nemuro
# Processing Record 18 of Set 6 | qandahar
# City not found. Skipping...
# Processing Record 19 of Set 6 | salalah
# Processing Record 20 of Set 6 | sambava
# Processing Record 21 of Set 6 | aguilas
# Processing Record 22 of Set 6 | anna paulowna
# Processing Record 23 of Set 6 | shahrud
# Processing Record 24 of Set 6 | lichinga
# Processing Record 25 of Set 6 | lavrentiya
# Processing Record 26 of Set 6 | teya
# Processing Record 27 of Set 6 | oussouye
# Processing Record 28 of Set 6 | acuna
# City not found. Skipping...
# Processing Record 29 of Set 6 | iqaluit
# Processing Record 30 of Set 6 | polson
# Processing Record 31 of Set 6 | oranjemund
# Processing Record 32 of Set 6 | ambon
# Processing Record 33 of Set 6 | naze
# Processing Record 34 of Set 6 | havre-saint-pierre
# Processing Record 35 of Set 6 | mormugao
# Processing Record 36 of Set 6 | gamba
# Processing Record 37 of Set 6 | hofn
# Processing Record 38 of Set 6 | labuhan
# Processing Record 39 of Set 6 | rio das ostras
# Processing Record 40 of Set 6 | pangkalanbuun
# Processing Record 41 of Set 6 | puteyets
# Processing Record 42 of Set 6 | kalispell
# Processing Record 43 of Set 6 | severnyy
# Processing Record 44 of Set 6 | puerto el triunfo
# Processing Record 45 of Set 6 | palmer
# Processing Record 46 of Set 6 | dharchula
# Processing Record 47 of Set 6 | presidencia roque saenz pena
# Processing Record 48 of Set 6 | zhangye
# Processing Record 49 of Set 6 | oltu
# Processing Record 50 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 7 | port lincoln
# Processing Record 2 of Set 7 | rudnytsya
# City not found. Skipping...
# Processing Record 3 of Set 7 | broome
# Processing Record 4 of Set 7 | klaksvik
# Processing Record 5 of Set 7 | codrington
# Processing Record 6 of Set 7 | port-cartier
# Processing Record 7 of Set 7 | kirakira
# Processing Record 8 of Set 7 | magistralnyy
# Processing Record 9 of Set 7 | kapoeta
# Processing Record 10 of Set 7 | aripuana
# Processing Record 11 of Set 7 | srednekolymsk
# Processing Record 12 of Set 7 | miami
# Processing Record 13 of Set 7 | meulaboh
# Processing Record 14 of Set 7 | semnan
# Processing Record 15 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 7 | along
# Processing Record 17 of Set 7 | kavaratti
# Processing Record 18 of Set 7 | san jose
# Processing Record 19 of Set 7 | pita
# Processing Record 20 of Set 7 | samdrup jongkhar
# Processing Record 21 of Set 7 | ambanja
# Processing Record 22 of Set 7 | victor harbor
# Processing Record 23 of Set 7 | jibuti
# Processing Record 24 of Set 7 | darhan
# Processing Record 25 of Set 7 | natal
# Processing Record 26 of Set 7 | roma
# Processing Record 27 of Set 7 | annan
# Processing Record 28 of Set 7 | tecoanapa
# Processing Record 29 of Set 7 | muravlenko
# Processing Record 30 of Set 7 | petrovsk
# Processing Record 31 of Set 7 | bilaspur
# Processing Record 32 of Set 7 | chifeng
# Processing Record 33 of Set 7 | subaytilah
# City not found. Skipping...
# Processing Record 34 of Set 7 | verkhniy baskunchak
# Processing Record 35 of Set 7 | atar
# Processing Record 36 of Set 7 | koungou
# Processing Record 37 of Set 7 | coquimbo
# Processing Record 38 of Set 7 | nsanje
# Processing Record 39 of Set 7 | asosa
# Processing Record 40 of Set 7 | muros
# Processing Record 41 of Set 7 | chongwe
# Processing Record 42 of Set 7 | bafut
# Processing Record 43 of Set 7 | komsomolskiy
# Processing Record 44 of Set 7 | pathein
# Processing Record 45 of Set 7 | bayanday
# Processing Record 46 of Set 7 | cabo san lucas
# Processing Record 47 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 7 | lompoc
# Processing Record 49 of Set 7 | bayburt
# Processing Record 50 of Set 7 | pavagada
# Processing Record 1 of Set 8 | bathsheba
# Processing Record 2 of Set 8 | lowestoft
# Processing Record 3 of Set 8 | nikel
# Processing Record 4 of Set 8 | manfredonia
# Processing Record 5 of Set 8 | westport
# Processing Record 6 of Set 8 | trincomalee
# Processing Record 7 of Set 8 | valkeala
# Processing Record 8 of Set 8 | geraldton
# Processing Record 9 of Set 8 | manturovo
# Processing Record 10 of Set 8 | vao
# Processing Record 11 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 8 | kemijarvi
# Processing Record 13 of Set 8 | yiyang
# Processing Record 14 of Set 8 | elko
# Processing Record 15 of Set 8 | mitsamiouli
# Processing Record 16 of Set 8 | lafia
# Processing Record 17 of Set 8 | arvika
# Processing Record 18 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 8 | shitanjing
# Processing Record 20 of Set 8 | rio gallegos
# Processing Record 21 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 8 | itaituba
# Processing Record 23 of Set 8 | valea argovei
# Processing Record 24 of Set 8 | dauriya
# Processing Record 25 of Set 8 | sydney
# Processing Record 26 of Set 8 | laguna
# Processing Record 27 of Set 8 | sept-iles
# Processing Record 28 of Set 8 | severodvinsk
# Processing Record 29 of Set 8 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 30 of Set 8 | tual
# Processing Record 31 of Set 8 | mokhsogollokh
# Processing Record 32 of Set 8 | suifenhe
# Processing Record 33 of Set 8 | pacifica
# Processing Record 34 of Set 8 | toftir
# City not found. Skipping...
# Processing Record 35 of Set 8 | hongan
# City not found. Skipping...
# Processing Record 36 of Set 8 | porbandar
# Processing Record 37 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 8 | manado
# Processing Record 39 of Set 8 | chengde
# Processing Record 40 of Set 8 | halifax
# Processing Record 41 of Set 8 | moravsky krumlov
# Processing Record 42 of Set 8 | marzuq
# Processing Record 43 of Set 8 | kolyvan
# Processing Record 44 of Set 8 | union
# Processing Record 45 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 46 of Set 8 | tura
# Processing Record 47 of Set 8 | isangel
# Processing Record 48 of Set 8 | naryan-mar
# Processing Record 49 of Set 8 | kaeo
# Processing Record 50 of Set 8 | shira
# Processing Record 1 of Set 9 | burnie
# Processing Record 2 of Set 9 | saint-georges
# Processing Record 3 of Set 9 | chandbali
# Processing Record 4 of Set 9 | port hardy
# Processing Record 5 of Set 9 | ochamchira
# Processing Record 6 of Set 9 | samarai
# Processing Record 7 of Set 9 | behshahr
# Processing Record 8 of Set 9 | sistranda
# Processing Record 9 of Set 9 | makakilo city
# Processing Record 10 of Set 9 | rio branco
# Processing Record 11 of Set 9 | saldanha
# Processing Record 12 of Set 9 | shemgang
# Processing Record 13 of Set 9 | miri
# Processing Record 14 of Set 9 | constitucion
# Processing Record 15 of Set 9 | mayo
# Processing Record 16 of Set 9 | nome
# Processing Record 17 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 9 | morondava
# Processing Record 19 of Set 9 | lac du bonnet
# Processing Record 20 of Set 9 | marawi
# Processing Record 21 of Set 9 | hameenlinna
# Processing Record 22 of Set 9 | upington
# Processing Record 23 of Set 9 | ust-koksa
# Processing Record 24 of Set 9 | gunjur
# Processing Record 25 of Set 9 | port hawkesbury
# Processing Record 26 of Set 9 | kloulklubed
# Processing Record 27 of Set 9 | sorland
# Processing Record 28 of Set 9 | kharitonovo
# Processing Record 29 of Set 9 | fortuna foothills
# Processing Record 30 of Set 9 | chimore
# Processing Record 31 of Set 9 | san clemente
# Processing Record 32 of Set 9 | kenai
# Processing Record 33 of Set 9 | tongliao
# Processing Record 34 of Set 9 | kodinsk
# Processing Record 35 of Set 9 | cockburn town
# Processing Record 36 of Set 9 | andra
# Processing Record 37 of Set 9 | syracuse
# Processing Record 38 of Set 9 | mount isa
# Processing Record 39 of Set 9 | lata
# Processing Record 40 of Set 9 | saint-augustin
# Processing Record 41 of Set 9 | farafangana
# Processing Record 42 of Set 9 | youhao
# Processing Record 43 of Set 9 | aykhal
# Processing Record 44 of Set 9 | talcahuano
# Processing Record 45 of Set 9 | sloboda
# Processing Record 46 of Set 9 | altay
# Processing Record 47 of Set 9 | haines junction
# Processing Record 48 of Set 9 | bubaque
# Processing Record 49 of Set 9 | margate
# Processing Record 50 of Set 9 | cabedelo
# Processing Record 1 of Set 10 | colwyn bay
# Processing Record 2 of Set 10 | uruacu
# Processing Record 3 of Set 10 | axim
# Processing Record 4 of Set 10 | florence
# Processing Record 5 of Set 10 | chicama
# Processing Record 6 of Set 10 | college
# Processing Record 7 of Set 10 | chapais
# Processing Record 8 of Set 10 | walvis bay
# Processing Record 9 of Set 10 | tahoua
# Processing Record 10 of Set 10 | kaitangata
# Processing Record 11 of Set 10 | okhotsk
# Processing Record 12 of Set 10 | krasnokamensk
# Processing Record 13 of Set 10 | balkhash
# Processing Record 14 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 10 | port keats
# Processing Record 16 of Set 10 | wapi pathum
# Processing Record 17 of Set 10 | katsuura
# Processing Record 18 of Set 10 | quatre cocos
# Processing Record 19 of Set 10 | dhangadhi
# Processing Record 20 of Set 10 | high level
# Processing Record 21 of Set 10 | beckerich
# Processing Record 22 of Set 10 | niamey
# Processing Record 23 of Set 10 | cairns
# Processing Record 24 of Set 10 | kibungo
# Processing Record 25 of Set 10 | emerald
# Processing Record 26 of Set 10 | mizdah
# Processing Record 27 of Set 10 | benguela
# Processing Record 28 of Set 10 | fort nelson
# Processing Record 29 of Set 10 | flinders
# Processing Record 30 of Set 10 | mackenzie
# Processing Record 31 of Set 10 | riyadh
# Processing Record 32 of Set 10 | kulhudhuffushi
# Processing Record 33 of Set 10 | manaure
# Processing Record 34 of Set 10 | qaqortoq
# Processing Record 35 of Set 10 | asau
# Processing Record 36 of Set 10 | jiuquan
# Processing Record 37 of Set 10 | valdemarpils
# Processing Record 38 of Set 10 | henties bay
# Processing Record 39 of Set 10 | odienne
# Processing Record 40 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 41 of Set 10 | dubrovytsya
# Processing Record 42 of Set 10 | puerto leguizamo
# Processing Record 43 of Set 10 | ayr
# Processing Record 44 of Set 10 | bakchar
# Processing Record 45 of Set 10 | chany
# Processing Record 46 of Set 10 | tarves
# Processing Record 47 of Set 10 | glassboro
# Processing Record 48 of Set 10 | praya
# Processing Record 49 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 10 | pitimbu
# Processing Record 1 of Set 11 | bengkalis
# City not found. Skipping...
# Processing Record 2 of Set 11 | ahipara
# Processing Record 3 of Set 11 | namatanai
# Processing Record 4 of Set 11 | poronaysk
# Processing Record 5 of Set 11 | weihai
# Processing Record 6 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 11 | malindi
# Processing Record 8 of Set 11 | la paz
# Processing Record 9 of Set 11 | moshenskoye
# Processing Record 10 of Set 11 | nalut
# Processing Record 11 of Set 11 | sosnovo-ozerskoye
# Processing Record 12 of Set 11 | cap malheureux
# Processing Record 13 of Set 11 | kayes
# Processing Record 14 of Set 11 | marshall
# Processing Record 15 of Set 11 | swan hill
# Processing Record 16 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 11 | macherla
# Processing Record 18 of Set 11 | ambulu
# Processing Record 19 of Set 11 | sao miguel do araguaia
# Processing Record 20 of Set 11 | wanning
# Processing Record 21 of Set 11 | merauke
# Processing Record 22 of Set 11 | ashland
# Processing Record 23 of Set 11 | obihiro
# Processing Record 24 of Set 11 | tuatapere
# Processing Record 25 of Set 11 | warmbad
# Processing Record 26 of Set 11 | kitimat
# Processing Record 27 of Set 11 | olinda
# Processing Record 28 of Set 11 | samaniego
# Processing Record 29 of Set 11 | bull savanna
# Processing Record 30 of Set 11 | tikhvin
# Processing Record 31 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 32 of Set 11 | morristown
# Processing Record 33 of Set 11 | baruun-urt
# Processing Record 34 of Set 11 | necochea
# Processing Record 35 of Set 11 | novyye lyady
# Processing Record 36 of Set 11 | navalmoral de la mata
# Processing Record 37 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 11 | iranshahr
# Processing Record 39 of Set 11 | atambua
# Processing Record 40 of Set 11 | northam
# Processing Record 41 of Set 11 | hambantota
# Processing Record 42 of Set 11 | skibbereen
# Processing Record 43 of Set 11 | chateaubelair
# Processing Record 44 of Set 11 | kenora
# Processing Record 45 of Set 11 | chokwe
# Processing Record 46 of Set 11 | la ronge
# Processing Record 47 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 11 | narsaq
# Processing Record 49 of Set 11 | swinford
# Processing Record 50 of Set 11 | ust-omchug
# Processing Record 1 of Set 12 | salinopolis
# Processing Record 2 of Set 12 | fare
# Processing Record 3 of Set 12 | ordynskoye
# Processing Record 4 of Set 12 | odda
# Processing Record 5 of Set 12 | tessalit
# Processing Record 6 of Set 12 | atbasar
# Processing Record 7 of Set 12 | yagodnoye
# Processing Record 8 of Set 12 | saint-pierre-des-corps
# Processing Record 9 of Set 12 | saint-joseph
# Processing Record 10 of Set 12 | porto novo
# Processing Record 11 of Set 12 | leon valley
# Processing Record 12 of Set 12 | ketchikan
# Processing Record 13 of Set 12 | brownsville
# Processing Record 14 of Set 12 | podor
# Processing Record 15 of Set 12 | santa vitoria
# Processing Record 16 of Set 12 | omboue
# Processing Record 17 of Set 12 | kalmar
# Processing Record 18 of Set 12 | pangai
# Processing Record 19 of Set 12 | sao jose da coroa grande
# Processing Record 20 of Set 12 | bangangte
# Processing Record 21 of Set 12 | eureka
# Processing Record 22 of Set 12 | ipixuna
# Processing Record 23 of Set 12 | maniitsoq
# Processing Record 24 of Set 12 | norwich
# Processing Record 25 of Set 12 | omagh
# Processing Record 26 of Set 12 | mogzon
# Processing Record 27 of Set 12 | alto araguaia
# Processing Record 28 of Set 12 | sholapur
# Processing Record 29 of Set 12 | adrar
# Processing Record 30 of Set 12 | daru
# Processing Record 31 of Set 12 | katav-ivanovsk
# Processing Record 32 of Set 12 | korampallam
# Processing Record 33 of Set 12 | los andes
# Processing Record 34 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 35 of Set 12 | fairbanks
# Processing Record 36 of Set 12 | urengoy
# Processing Record 37 of Set 12 | huangnihe
# Processing Record 38 of Set 12 | ishigaki
# Processing Record 39 of Set 12 | kambove
# Processing Record 40 of Set 12 | portland
# Processing Record 41 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 12 | sobolevo
# Processing Record 43 of Set 12 | abu kamal
# Processing Record 44 of Set 12 | simao
# Processing Record 45 of Set 12 | villa de cura
# Processing Record 46 of Set 12 | lixourion
# Processing Record 47 of Set 12 | umtata
# Processing Record 48 of Set 12 | mwinilunga
# Processing Record 49 of Set 12 | mackay
# Processing Record 50 of Set 12 | umm ruwabah
# City not found. Skipping...
# Processing Record 1 of Set 13 | saint-pierre
# Processing Record 2 of Set 13 | esil
# Processing Record 3 of Set 13 | bara
# Processing Record 4 of Set 13 | port blair
# Processing Record 5 of Set 13 | aquiraz
# Processing Record 6 of Set 13 | rawson
# Processing Record 7 of Set 13 | chalchihuites
# Processing Record 8 of Set 13 | jalu
# Processing Record 9 of Set 13 | coihueco
# Processing Record 10 of Set 13 | saalfeld
# Processing Record 11 of Set 13 | nouakchott
# Processing Record 12 of Set 13 | roald
# Processing Record 13 of Set 13 | shenjiamen
# Processing Record 14 of Set 13 | zhongshu
# Processing Record 15 of Set 13 | colares
# Processing Record 16 of Set 13 | deputatskiy
# Processing Record 17 of Set 13 | arlit
# Processing Record 18 of Set 13 | anadyr
# Processing Record 19 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 13 | shache
# Processing Record 21 of Set 13 | trat
# Processing Record 22 of Set 13 | palmerston
# Processing Record 23 of Set 13 | mandera
# Processing Record 24 of Set 13 | gorkovskoye
# City not found. Skipping...
# Processing Record 25 of Set 13 | mandalgovi
# Processing Record 26 of Set 13 | mahibadhoo
# Processing Record 27 of Set 13 | petropavlovka
# Processing Record 28 of Set 13 | chapleau
# Processing Record 29 of Set 13 | bonthe
# Processing Record 30 of Set 13 | taksimo
# Processing Record 31 of Set 13 | port-de-bouc
# Processing Record 32 of Set 13 | votkinsk
# Processing Record 33 of Set 13 | eugene
# Processing Record 34 of Set 13 | camocim
# Processing Record 35 of Set 13 | nouadhibou
# Processing Record 36 of Set 13 | omsukchan
# Processing Record 37 of Set 13 | marsh harbour
# Processing Record 38 of Set 13 | vilyuysk
# Processing Record 39 of Set 13 | sur
# Processing Record 40 of Set 13 | zemetchino
# Processing Record 41 of Set 13 | ituacu
# Processing Record 42 of Set 13 | tutin
# Processing Record 43 of Set 13 | hamilton
# Processing Record 44 of Set 13 | igarka
# Processing Record 45 of Set 13 | akhtanizovskaya
# Processing Record 46 of Set 13 | usinsk
# Processing Record 47 of Set 13 | vostok
# Processing Record 48 of Set 13 | moose factory
# Processing Record 49 of Set 13 | puerto escondido
# Processing Record 50 of Set 13 | joshimath

# %%
len(city_data)

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)

# %%
city_data_df.columns

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)

# %%
city_data_df.dtypes

# %%
# Create the output File (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
